# %%
# 주피터 파일명 == 모듈명(라이브러리명)
# 일반적으로 모듈명은 내장된 기능들을 아우르는 (포괄하는) 개념이 좋음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import module_test
# module_test 모듈의 전체 기능을 다 불러오겠다!

# %%
module_test.add(10,5)
# Out:
# 15

# %%
module_test.sub(10,5)
# Out:
# 5

# %%
# 함수 한 개만 불러오기
from module_test import add
add(10,7)
# Out:
# 17

# %%
sub(10,7)
# Out:
# 3

# %%
# module_test.add()
# 별칭을 불러주기
import module_test as mt
mt.add(10,5)
# Out:
# 15

# %% [markdown]
# ![image.png](attachment:image.png)
